# %%
from pystac_client import Client
import planetary_computer as pc

# Search against the Planetary Computer STAC API
catalog = Client.open(
  "https://planetarycomputer.microsoft.com/api/stac/v1"
)

# Define your area of interest
aoi = {
  "type": "Polygon",
  "coordinates": [
    [
      [-60.66972399381274, -30.011158416757837],
      [-29.436761271971335, -30.011158416757837],
      [-29.436761271971335, -10.879530861595242],
      [-60.66972399381274, -10.879530861595242],
      [-60.66972399381274, -30.011158416757837]
    ]
  ]
}

# Define your search with CQL2 syntax
search = catalog.search(filter_lang="cql2-json", filter={
  "op": "and",
  "args": [
    {"op": "s_intersects", "args": [{"property": "geometry"}, aoi]},
    {"op": "=", "args": [{"property": "collection"}, "modis-14A1-061"]}
  ]
})

# Grab the first item from the search results and sign the assets
first_item = next(search.get_items())
pc.sign_item(first_item).assets
# Out:
# /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac_client/item_search.py:826: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# {'QA': <Asset href=https://modiseuwest.blob.core.windows.net/modis-061-cogs/MYD14A1/15/11/2023265/MYD14A1.A2023265.h15v11.061.2023274000358_QA.tif?st=2023-10-06T01%3A59%3A39Z&se=2023-10-14T01%3A59%3A40Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-10-07T01%3A59%3A38Z&ske=2023-10-14T01%3A59%3A38Z&sks=b&skv=2021-06-08&sig=WQxDUi6v4EmHGUzUXbQjaGDE6slvRvR3U6EZAGorGBI%3D>,
# ...

# %%
from pystac_client import Client
import planetary_computer as pc

# Search against the Planetary Computer STAC API
catalog = Client.open(
  "https://planetarycomputer.microsoft.com/api/stac/v1"
)

# Define your area of interest
aoi = {
  "type": "Polygon",
  "coordinates": [
    [
      [-54.69241868605391, -23.389107710541325],
      [-44.77861983468577, -23.389107710541325],
      [-44.77861983468577, -17.27931162934047],
      [-54.69241868605391, -17.27931162934047],
      [-54.69241868605391, -23.389107710541325]
    ]
  ]
}

# Define your temporal range
daterange = {"interval": ["2000-02-24T00:00:00Z", "2023-10-07T23:59:59Z"]}

# Define your search with CQL2 syntax
search = catalog.search(filter_lang="cql2-json", filter={
  "op": "and",
  "args": [
    {"op": "s_intersects", "args": [{"property": "geometry"}, aoi]},
    {"op": "anyinteracts", "args": [{"property": "datetime"}, daterange]},
    {"op": "=", "args": [{"property": "collection"}, "modis-11A1-061"]}
  ]
})

# Grab the first item from the search results and sign the assets
first_item = next(search.get_items())
pc.sign_item(first_item).assets
# Out:
# {'hdf': <Asset href=https://modiseuwest.blob.core.windows.net/modis-061/MYD11A1/13/11/2023277/MYD11A1.A2023277.h13v11.061.2023278234055.hdf?st=2023-10-06T01%3A59%3A40Z&se=2023-10-14T01%3A59%3A40Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-10-07T01%3A59%3A39Z&ske=2023-10-14T01%3A59%3A39Z&sks=b&skv=2021-06-08&sig=wvOXaJ8Eb8jOsMm1jR6rtYf87zsuiUglA0n5VBuIdpQ%3D>,
#  'QC_Day': <Asset href=https://modiseuwest.blob.core.windows.net/modis-061-cogs/MYD11A1/13/11/2023277/MYD11A1.A2023277.h13v11.061.2023278234055_QC_Day.tif?st=2023-10-06T01%3A59%3A39Z&se=2023-10-14T01%3A59%3A40Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-10-07T01%3A59%3A38Z&ske=2023-10-14T01%3A59%3A38Z&sks=b&skv=2021-06-08&sig=WQxDUi6v4EmHGUzUXbQjaGDE6slvRvR3U6EZAGorGBI%3D>,
# ...

# %%
search.get_items()
# Out:
# /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac_client/item_search.py:826: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# <generator object ItemSearch.items at 0x7f4a787c95d0>

# %%
first_item
# Out:
# <Item id=MYD11A1.A2023277.h13v11.061.2023278234055>
